# %% [markdown]
# # PRACTICE WEEK-2

# %% [markdown]
# # Numerical Computing Foundations & Numpy Internals
#
# **Course:** Applied Data Engineering with Python
#
# **Focus:** Memory Model, Vectorization, ndarry Internals

# %% [markdown]
# 1. Why pure Python is Slow for Numerical Computing
#
#    Python Object overhead
#
#    Dynamic typing cost
#
#    Loop overhead
#
#    Memory access patterns

# %%
import time
n = 10_000_000
a = list(range(n))
b = list(range(n))
start = time.time()
c = [a[i] + b[i] for i in range(n)]
end = time.time()
print('Python loop time:',end - start)
# Out:
# Python loop time: 1.9024572372436523

# %% [markdown]
# # 2. NumPy Vectorization Benchmark
# Vectorized operations execute in optimized C code

# %%
import numpy as np
a = np.arange(n)
b = np.arange(n)
start = time.time()
c = a + b
end = time.time()
print('Numpy vectorized time:',end - start)
# Out:
# Numpy vectorized time: 0.3311960697174072

# %% [markdown]
# # 3. ndarray Internals
